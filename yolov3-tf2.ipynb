# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyes-hamrouni/first-contributions/blob/master/yolov3-tf2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu==2.0.0a0
# !pip install opencv-python==4.0.0.21

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/zzh8829/yolov3-tf2.git

# %%
# %cd yolov3-tf2
# !ls

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O data/yolov3.weights
# !python convert.py

# %%
# !pwd

# %%
# !python detect.py --weights ./checkpoints/yolov3_train_10.tf --image ./data/fire6.jpeg
# Out:
# 2019-07-29 12:37:57.520119: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-29 12:37:57.525323: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-07-29 12:37:57.617847: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1009] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-07-29 12:37:57.618986: I tensorflow/compiler/xla/service/service.cc:162] XLA service 0x1b28680 executing computations on platform CUDA. Devices:
# 2019-07-29 12:37:57.619045: I tensorflow/compiler/xla/service/service.cc:169]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-07-29 12:37:57.621509: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread('output.jpg'))

# %%
# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('/content/drive')csv to tfrecord

# %%
# !pwd
# Out:
# /content/yolov3-tf2

# %%
# !python train.py --batch_size 10 --dataset data/train.record --val_dataset data/test.record --epochs 10 --mode fit --transfer none
# Out:
# 2019-07-29 11:08:57.137270: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-29 11:08:57.142157: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-07-29 11:08:57.234966: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1009] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-07-29 11:08:57.236086: I tensorflow/compiler/xla/service/service.cc:162] XLA service 0x2b3e680 executing computations on platform CUDA. Devices:
# 2019-07-29 11:08:57.236126: I tensorflow/compiler/xla/service/service.cc:169]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-07-29 11:08:57.239036: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# ...
